# %% [markdown]
# # **`pepper_abstract.py` testing**

# %% [markdown]
# # Data for tests

# %%
from olist_commons import get_order_items
get_order_items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\franc\Projects\pepper_olist_market_segmentation\jupyter\pepper_abstraction_tests.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/Projects/pepper_olist_market_segmentation/jupyter/pepper_abstraction_tests.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from olist_commons import get_order_items
# ----> <a href='vscode-notebook-cell:/c%3A/Users/franc/Projects/pepper_olist_market_segmentation/jupyter/pepper_abstraction_tests.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> get_order_items()
#
# File c:\Users\franc\Projects\pepper_olist_market_segmentation\jupyter\olist_commons.py:592, in get_order_items(orders_index, products_index, sellers_index)
#     589     # Save to the cache global variable
#     590     _cached_order_items = oi
# --> 592 return filtered_copy(
#     593     _cached_order_items,
# ...

# %%
from olist_commons import get_order_items_multi_index
get_order_items_multi_index()
# Out:
# order_items                                                           product_id  \
# order_id                         order_item_id
# 00010242fe8c5a6d1ba2dd792cb16214 1              4244733e06e7ecb4970a6e2683c13e61
# 00018f77f2f0320c557190d7a144bdd3 1              e5f2d52b802189ee658865ca93d83a8f
# 000229ec398224ef6ca0657da4fc703e 1              c777355d18b72b67abbeef9df44fd0fd
# 00024acbcdf0a6daa1e931b038114c75 1              7634da152a4610f1595efa32f14722fc
# 00042b26cf59d7ce69dfabb4e55b4fd9 1              ac6c3623068f30de03045865e4e10089
# ...                                                                          ...
# fffc94f6ce00a00581880bf54a75a037 1              4aa6014eceb682077f9dc4bffebc05b0
# fffcd46ef2263f404302a634eb57f7eb 1              32e07fd915822b0765e448c4dd74c828
# fffce4705a9662cd70adb13d4a31832d 1              72a30483855e2eafc67aee5dc2560482
# fffe18544ffabc95dfada21779c9644f 1              9c422a519119dcad7575db5af1ba540e
# ...

# %%
from olist_commons import (
    bypass_filtered_copy_get_order_items,
    bypass_filtered_copy_get_order_items_multi_index
)
order_items = bypass_filtered_copy_get_order_items()
order_items_mi = bypass_filtered_copy_get_order_items_multi_index()
display(order_items)
# Out:
# order_items                                                  product_id  \
# (order_id, order_item_id)
# (00010242fe8c5a6d1ba2dd792cb16214, 1)  4244733e06e7ecb4970a6e2683c13e61
# (00018f77f2f0320c557190d7a144bdd3, 1)  e5f2d52b802189ee658865ca93d83a8f
# (000229ec398224ef6ca0657da4fc703e, 1)  c777355d18b72b67abbeef9df44fd0fd
# (00024acbcdf0a6daa1e931b038114c75, 1)  7634da152a4610f1595efa32f14722fc
# (00042b26cf59d7ce69dfabb4e55b4fd9, 1)  ac6c3623068f30de03045865e4e10089
# ...                                                                 ...
# (fffc94f6ce00a00581880bf54a75a037, 1)  4aa6014eceb682077f9dc4bffebc05b0
# (fffcd46ef2263f404302a634eb57f7eb, 1)  32e07fd915822b0765e448c4dd74c828
# (fffce4705a9662cd70adb13d4a31832d, 1)  72a30483855e2eafc67aee5dc2560482
# (fffe18544ffabc95dfada21779c9644f, 1)  9c422a519119dcad7575db5af1ba540e
# (fffe41c64501cc87c801fd61db3f6244, 1)  350688d9dc1e75ff97be326363655e01
#
# order_items                                                   seller_id  \
# ...

# %% [markdown]
# # Tests

# %%
from pepper_abstraction import DataWrapper

dw = DataWrapper(order_items)
display(dw['seller_id'])

for k, v in dw.items():
    display(v)
# Out:
# (order_id, order_item_id)
# (00010242fe8c5a6d1ba2dd792cb16214, 1)    48436dade18ac8b2bce089ec2a041202
# (00018f77f2f0320c557190d7a144bdd3, 1)    dd7ddc04e1b6c2c614352b383efe2d36
# (000229ec398224ef6ca0657da4fc703e, 1)    5b51032eddd242adc84c38acab88f23d
# (00024acbcdf0a6daa1e931b038114c75, 1)    9d7a1d34a5052409006425275ba1c2b4
# (00042b26cf59d7ce69dfabb4e55b4fd9, 1)    df560393f3a51e74553ab94004ba5c87
#                                                        ...
# (fffc94f6ce00a00581880bf54a75a037, 1)    b8bc237ba3788b23da09c0f1f3a3288c
# (fffcd46ef2263f404302a634eb57f7eb, 1)    f3c38ab652836d21de61fb8314b69182
# (fffce4705a9662cd70adb13d4a31832d, 1)    c3cfdc648177fdbbbb35635a37472c53
# (fffe18544ffabc95dfada21779c9644f, 1)    2b3e4a2a3ea8e01938cabda2a3e5cc79
# (fffe41c64501cc87c801fd61db3f6244, 1)    f7ccf836d21b2fb1de37564105216cc1
# Name: seller_id, Length: 112650, dtype: object
# ---------------------------------------------------------------------------
# ...
